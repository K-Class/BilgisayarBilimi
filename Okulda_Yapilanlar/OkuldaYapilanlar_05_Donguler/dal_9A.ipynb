# %%
print("Adım",1)
print("Adım",2)
print("Adım",3)
print("Adım",4)
print("Adım",5)


print('\nProgram Sonlandırıldı')
# Out:
# Adım 1
# Adım 2
# Adım 3
# Adım 4
# Adım 5
#
# Program Sonlandırıldı

# %%
sayaç = 0

while sayaç < 5 :
    sayaç = sayaç + 1 
    print("Adım ",sayaç)

print('\nProgram Sonlandırıldı')
# Out:
# Adım  1
# Adım  2
# Adım  3
# Adım  4
# Adım  5
#
# Program Sonlandırıldı

# %%
sayaç = 0

while sayaç < 1000 :
    sayaç = sayaç + 1 
    print("Adım ",sayaç)

print('\nProgram Sonlandırıldı')
# Out:
# Adım  1
# Adım  2
# Adım  3
# Adım  4
# Adım  5
# Adım  6
# Adım  7
# Adım  8
# Adım  9
# Adım  10
# Adım  11
# Adım  12
# Adım  13
# Adım  14
# Adım  15
# Adım  16
# Adım  17
# Adım  18
# Adım  19
# Adım  20
# Adım  21
# Adım  22
# Adım  23
# Adım  24
# Adım  25
# Adım  26
# Adım  27
# Adım  28
# Adım  29
# Adım  30
# Adım  31
# Adım  32
# Adım  33
# Adım  34
# Adım  35
# Adım  36
# Adım  37
# Adım  38
# Adım  39
# Adım  40
# Adım  41
# Adım  42
# Adım  43
# Adım  44
# Adım  45
# Adım  46
# Adım  47
# Adım  48
# Adım  49
# Adım  50
# Adım  51
# Adım  52
# Adım  53
# Adım  54
# Adım  55
# Adım  56
# Adım  57
# Adım  58
# Adım  59
# Adım  60
# Adım  61
# Adım  62
# Adım  63
# Adım  64
# Adım  65
# Adım  66
# Adım  67
# Adım  68
# Adım  69
# Adım  70
# Adım  71
# Adım  72
# Adım  73
# Adım  74
# Adım  75
# Adım  76
# Adım  77
# Adım  78
# Adım  79
# Adım  80
# Adım  81
# Adım  82
# Adım  83
# Adım  84
# Adım  85
# Adım  86
# Adım  87
# Adım  88
# Adım  89
# Adım  90
# Adım  91
# ...

# %%
sayaç = 0 
toplam = 0

while sayaç < 10 :
    sayaç += 1 # sayaç = sayaç + 1 demek
    toplam = sayaç + toplam
    print("{}.Adımda Toplam ={}".format(sayaç,toplam))

print(toplam)
# Out:
# 1.Adımda Toplam =1
# 2.Adımda Toplam =3
# 3.Adımda Toplam =6
# 4.Adımda Toplam =10
# 5.Adımda Toplam =15
# 6.Adımda Toplam =21
# 7.Adımda Toplam =28
# 8.Adımda Toplam =36
# 9.Adımda Toplam =45
# 10.Adımda Toplam =55
# 55

# %%
print("Çıkmak için 'ç' hargini girin")
sayaç = 0
toplam = 0
sayı = input("Toplanacak Sayı Değerini Girin:") # string değer alır

while sayı != "ç" :
    sayaç +=1
    toplam = toplam + int(sayı) # string olan sayıyı int'e çevirir
    sayı = input("Toplanacak Sayı Değerini Girin:")

print("{} Adet Girilen Sayının Toplamı : {}".format(sayaç,toplam))
print('\nProgram Sonlandırıldı')
# Out:
# Çıkmak için 'ç' hargini girin
# Toplanacak Sayı Değerini Girin:2
# Toplanacak Sayı Değerini Girin:4
# Toplanacak Sayı Değerini Girin:6
# Toplanacak Sayı Değerini Girin:8
# Toplanacak Sayı Değerini Girin:ç
# 4 Adet Girilen Sayının Toplamı : 20
#
# Program Sonlandırıldı

# %%
# time(zaman) modülünü kodumuza ekliyoruz bu konu ileride görülecek
import time

sayaç = 0

while sayaç < 10 :
    # sayaç değişkeninin değeri artırılmıyor
    time.sleep(1)
    print('{}.Adım '.format(syç),end=" ")

print('Program Sonlandırıldı')
# Out:
# 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım 0.Adım
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-8db12520fdf6> in <module>()
#       6 while syç < 10 :
#       7     # syç değişkeninin değeri artırılmıyor
# ----> 8     time.sleep(1)
#       9     print('{}.Adım'.format(syç),end=" ")
#      10
#
# KeyboardInterrupt:
